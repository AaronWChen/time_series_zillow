# %%
import pandas as pd

# %%
zillow_df = pd.read_csv('zillow_data.csv')

# %%
#setting display options 

pd.set_option('display.max_rows', 500) 
pd.set_option('display.max_columns', 500)

# %%
zillow_df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0         1  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 1         2  235700.0  236900.0  236700.0  235400.0  233300.0  230600.0
# 2         3  210400.0  212200.0  212200.0  210700.0  208300.0  205500.0
# 3         4  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 4         5   77300.0   77300.0   77300.0   77300.0   77400.0   77500.0
#
#     1996-10   1996-11   1996-12   1997-01   1997-02   1997-03   1997-04  \
# ...

# %%
zillow_citygroup = zillow_df.groupby(['State', 'City'])
# zillow_citygroup.ngroups
# zillow_citygroup.groups.keys()

# %%
chicago_df = zillow_citygroup.get_group(('IL', 'Chicago'))
# chicago_df[chicago_df['RegionName']==60657].T.iloc[7:]
chicago_df.head()
# Out:
#     RegionID  RegionName     City State    Metro CountyName  SizeRank  \
# 0      84654       60657  Chicago    IL  Chicago       Cook         1
# 3      84616       60614  Chicago    IL  Chicago       Cook         4
# 7      84640       60640  Chicago    IL  Chicago       Cook         8
# 16     84646       60647  Chicago    IL  Chicago       Cook        17
# 19     84620       60618  Chicago    IL  Chicago       Cook        20
#
#      1996-04   1996-05   1996-06   1996-07   1996-08   1996-09   1996-10  \
# 0   334200.0  335400.0  336500.0  337600.0  338500.0  339500.0  340400.0
# 3   498100.0  500900.0  503100.0  504600.0  505500.0  505700.0  505300.0
# 7   216500.0  216700.0  216900.0  217000.0  217100.0  217200.0  217500.0
# 16  122700.0  122800.0  122800.0  122700.0  122400.0  122000.0  121500.0
# 19  142600.0  143100.0  143400.0  143300.0  142900.0  142200.0  141300.0
#
#      1996-11   1996-12   1997-01   1997-02   1997-03   1997-04   1997-05  \
# ...

# %%
pd.melt()
