# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as ply
from sklearn.model_selection import TimeSeriesSplit
from fbprophet import Prophet
# %matplotlib inline

# %%
df_actual = pd.read_csv("../write_data/San Jose.csv")
df_actual['time'] = pd.to_datetime(df_actual['time'])

# %%
df_fut = pd.read_csv("../write_data/San Jose_future.csv")
df_fut['ds'] = pd.to_datetime(df_fut['ds'])

# %%
zippies = df_fut.Zip_code.unique()

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[:10]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[10:20]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[20:30]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[30:40]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[40:50]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[50:]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %% [markdown]
# # 95023

# %%
df_actual[df_actual['Zip_code'] == 95023]
# Out:
#        Unnamed: 0  RegionName       City State     Metro  CountyName  \
# 15             15       95023  Hollister    CA  San Jose  San Benito
# 70             70       95023  Hollister    CA  San Jose  San Benito
# 125           125       95023  Hollister    CA  San Jose  San Benito
# 180           180       95023  Hollister    CA  San Jose  San Benito
# 235           235       95023  Hollister    CA  San Jose  San Benito
# ...           ...         ...        ...   ...       ...         ...
# 14315       14315       95023  Hollister    CA  San Jose  San Benito
# 14370       14370       95023  Hollister    CA  San Jose  San Benito
# 14425       14425       95023  Hollister    CA  San Jose  San Benito
# 14480       14480       95023  Hollister    CA  San Jose  San Benito
# 14535       14535       95023  Hollister    CA  San Jose  San Benito
#
#             time     value          ds     yhat_lower           yhat  \
# ...

# %%
# filt = df_actual[df_actual['Zip_code'] == 95023]

# plt.plot([filt['time'], filt['time']], 
#          [filt['value'], filt['yhat']], 
#          label=['actual', 'fbprophet'])

plt.plot(df_actual[df_actual['Zip_code'] == 95023]['time'], 
         df_actual[df_actual['Zip_code'] == 95023]['value'], 
         label='actual')

plt.plot(df_actual[df_actual['Zip_code'] == 95023]['time'], 
         df_actual[df_actual['Zip_code'] == 95023]['yhat'], 
         label='fbprophet')

plt.plot(df_fut[df_fut['Zip_code'] == 95023]['ds'], 
         df_fut[df_fut['Zip_code'] == 95023]['yhat'], 
         label='predict')

plt.plot(df_fut[df_fut['Zip_code'] == 95023]['ds'], 
         df_fut[df_fut['Zip_code'] == 95023]['yhat_lower'], 
         label='predict_lower')

plt.plot(df_fut[df_fut['Zip_code'] == 95023]['ds'], 
         df_fut[df_fut['Zip_code'] == 95023]['yhat_upper'], 
         label='predict_upper')

plt.legend(loc='best')
plt.show()

# %% [markdown]
# Prophet()

# %%
df_fut[df_fut['Zip_code'] == 95023]
# Out:
#      Unnamed: 0         ds     yhat_lower           yhat     yhat_upper  \
# 600        4776 2018-01-01  502482.180389  508896.396752  515150.648465
# 601        4777 2018-02-01  503667.829123  510185.091607  516217.429999
# 602        4778 2018-03-01  505265.139159  511451.962347  517767.458296
# 603        4779 2018-04-01  506367.936634  512128.614885  517912.513046
# 604        4780 2018-04-30  504799.326757  511031.182455  517569.282552
# 605        4781 2018-05-31  508455.667518  514694.680708  521223.532688
# 606        4782 2018-06-30  506519.453935  514444.848316  522109.935555
# 607        4783 2018-07-31  505846.337972  513987.906270  522783.644334
# 608        4784 2018-08-31  504600.586014  515073.350440  526105.112655
# 609        4785 2018-09-30  504436.633200  516365.793854  528945.769667
# 610        4786 2018-10-31  501297.828620  516976.915904  533740.306025
# 611        4787 2018-11-30  497450.381207  517270.355888  539037.362805
# ...

# %%
all_zips = pd.read_csv("../write_data/zillow_housing_zipcodes.csv")
all_zips['Date_index'] = pd.to_datetime(all_zips['Date_index'])
all_zips = all_zips.set_index('Date_index')

# %%
all_zips.columns
# Out:
# Index(['60657', '75070', '77494', '60614', '79936', '77084', '10467', '60640',
#        '77449', '94109',
#        ...
#        '3765', '84781', '12429', '97028', '12720', '1338', '3293', '40404',
#        '81225', '89155'],
#       dtype='object', length=14723)

# %%
zippies_strings = ["%.0f" % number for number in zippies]

# %%
zippies_strings
# Out:
# ['95123',
#  '95051',
#  '95035',
#  '95014',
#  '95112',
#  '94087',
#  '95125',
#  '94086',
#  '95008',
#  '95020',
#  '95124',
#  '95037',
#  '95136',
#  '95127',
#  '95111',
#  '95023',
#  '94040',
#  '95050',
#  '95126',
#  '94303',
#  '95129',
#  '95128',
#  '95134',
#  '94043',
#  '95116',
#  '95120',
#  '95122',
#  '95070',
#  '94306',
#  '95132',
#  '95148',
#  '95118',
#  '95032',
#  '95117',
#  '95121',
#  '95131',
#  '95133',
#  '95054',
#  '94089',
#  '94024',
#  '94301',
#  '94022',
#  '95135',
#  '94041',
#  '95110',
#  '95138',
#  '95030',
#  '95130',
#  '94305',
#  '95033',
#  '95119',
#  '95046',
#  '95139',
#  '95045',
#  '95004']

# %%
metro_zips = all_zips.filter(items=zippies_strings)
metro_zips
# Out:
#                 95123      95051      95035      95014     95112      94087  \
# Date_index
# 1996-04-01   224500.0   258700.0   231100.0   432400.0  186800.0   361300.0
# 1996-05-01   224800.0   259300.0   232100.0   434500.0  186800.0   363300.0
# 1996-06-01   225200.0   259900.0   233100.0   436700.0  186700.0   365300.0
# 1996-07-01   225700.0   260500.0   234200.0   439200.0  186600.0   367400.0
# 1996-08-01   226400.0   261100.0   235400.0   441900.0  186600.0   369600.0
# ...               ...        ...        ...        ...       ...        ...
# 2017-12-01   970700.0  1444500.0  1063700.0  2336900.0  834100.0  2092900.0
# 2018-01-01   986100.0  1476800.0  1076600.0  2374400.0  852200.0  2135200.0
# 2018-02-01  1002200.0  1508100.0  1096500.0  2416300.0  871200.0  2177400.0
# 2018-03-01  1025400.0  1547700.0  1131900.0  2464200.0  896300.0  2234000.0
# 2018-04-01  1043900.0  1577100.0  1160700.0  2490200.0  916100.0  2276300.0
#
# ...

# %%
actual_mean = metro_zips.mean(axis=1)

# %%
actual_mean
# Out:
# Date_index
# 1996-04-01    3.202655e+05
# 1996-05-01    3.217582e+05
# 1996-06-01    3.233236e+05
# 1996-07-01    3.249782e+05
# 1996-08-01    3.267273e+05
#                   ...
# 2017-12-01    1.557516e+06
# 2018-01-01    1.580244e+06
# 2018-02-01    1.605442e+06
# 2018-03-01    1.638996e+06
# 2018-04-01    1.661938e+06
# Length: 265, dtype: float64

# %%
plt.plot(actual_mean, label='mean')
plt.plot(df_actual[df_actual['Zip_code'] == 95023]['time'], 
         df_actual[df_actual['Zip_code'] == 95023]['value'], 
         label='actual')
plt.legend(loc='best')
plt.show()

# %%
plt.plot(df_actual[df_actual['Zip_code'] == 94022]['time'], 
         df_actual[df_actual['Zip_code'] == 94022]['value'], 
         label='actual')

plt.plot(df_actual[df_actual['Zip_code'] == 94022]['time'], 
         df_actual[df_actual['Zip_code'] == 94022]['yhat'], 
         label='fbprophet')

plt.plot(df_fut[df_fut['Zip_code'] == 94022]['ds'], 
         df_fut[df_fut['Zip_code'] == 94022]['yhat'], 
         label='predict')

plt.plot(df_fut[df_fut['Zip_code'] == 94022]['ds'], 
         df_fut[df_fut['Zip_code'] == 94022]['yhat_lower'], 
         label='predict_lower')

plt.plot(df_fut[df_fut['Zip_code'] == 94022]['ds'], 
         df_fut[df_fut['Zip_code'] == 94022]['yhat_upper'], 
         label='predict_upper')

plt.legend(loc='best')
plt.show()

# %%
df_fut[df_fut['Zip_code'] == 94022]
# Out:
#       Unnamed: 0         ds    yhat_lower          yhat    yhat_upper  \
# 1640       12602 2018-01-01  3.982673e+06  4.042018e+06  4.107807e+06
# 1641       12603 2018-02-01  4.012443e+06  4.075622e+06  4.136954e+06
# 1642       12604 2018-03-01  4.045109e+06  4.105420e+06  4.172912e+06
# 1643       12605 2018-04-01  4.071681e+06  4.137171e+06  4.199613e+06
# 1644       12606 2018-04-30  4.082414e+06  4.149037e+06  4.212496e+06
# 1645       12607 2018-05-31  4.128257e+06  4.188087e+06  4.255402e+06
# 1646       12608 2018-06-30  4.146311e+06  4.216259e+06  4.280280e+06
# 1647       12609 2018-07-31  4.184609e+06  4.245196e+06  4.312395e+06
# 1648       12610 2018-08-31  4.208354e+06  4.273728e+06  4.341229e+06
# 1649       12611 2018-09-30  4.229396e+06  4.304931e+06  4.372461e+06
# 1650       12612 2018-10-31  4.265714e+06  4.337846e+06  4.414537e+06
# 1651       12613 2018-11-30  4.283677e+06  4.367634e+06  4.446230e+06
# ...

# %%
for zippy in zippies:
    #plt.title(f"Housing Values in Zipcode:{title}")
    
    plt.plot(df_actual[df_actual['Zip_code'] == zippy]['time'], 
             df_actual[df_actual['Zip_code'] == zippy]['value'], 
             label=f'{zippy} actual')

    plt.plot(df_actual[df_actual['Zip_code'] == zippy]['time'], 
             df_actual[df_actual['Zip_code'] == zippy]['yhat'], 
             label=f'{zippy} fbprophet')

    plt.plot(df_fut[df_fut['Zip_code'] == zippy]['ds'], 
             df_fut[df_fut['Zip_code'] == zippy]['yhat'], 
             label=f'{zippy} predict')

    plt.plot(df_fut[df_fut['Zip_code'] == zippy]['ds'], 
             df_fut[df_fut['Zip_code'] == zippy]['yhat_lower'], 
             label=f'{zippy} predict_lower')

    plt.plot(df_fut[df_fut['Zip_code'] == zippy]['ds'], 
             df_fut[df_fut['Zip_code'] == zippy]['yhat_upper'], 
             label=f'{zippy} predict_upper')
    
    plt.legend(loc='best')
    plt.show()
