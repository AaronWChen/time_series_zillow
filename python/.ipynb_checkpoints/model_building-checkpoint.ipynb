# %%
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, acf, pacf
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARMA, ARIMA

# %%
## Making sure the data is stationary before feeding into our model

stationary_test = []
for col in model_one_df:
    for i in range(1, 10):
        adf_ = adfuller(model_one_df.diff(i).dropna()[col])[1]
        stationary_test.append((col, i, adf_))

[(i[0],i[1],i[2]) for i in stationary_test if i[2] <0.12]
# Out:
# [(11211, 3, 0.05583487694450467),
#  (11222, 7, 0.09985857151444733),
#  (11216, 8, 0.08161850203074883),
#  (20001, 7, 0.11451611012607399),
#  (19123, 8, 0.06477515553942259)]

# %%
stationary_test = []
for col in model_one_df:
    adf_ = adfuller(model_one_df.pct_change().dropna()[col])[1]
    stationary_test.append((col,adf_))

stationary_test
# Out:
# [(11211, 0.051048392445275266),
#  (11222, 0.0666706877058144),
#  (11216, 0.1911542497629078),
#  (20001, 0.12873129209197898),
#  (19123, 0.40975845623215856)]

# %%
# model_11211 = []
# for i in range(1, 10):
#     model_11211.append(ARMA(model_one_df[11211].diff(3).dropna().values, (1,i)).fit().bic)

# %%
model = ARMA(model_one_df[11211].pct_change().dropna().values, (3,1)).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4306bb04c83f> in <module>()
# ----> 1 model = ARMA(model_one_df[11211].pct_change().dropna().values, (3,1)).fit()
#
# NameError: name 'ARMA' is not defined

# %%
model.bic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-93e90e46576f> in <module>()
# ----> 1 model.bic
#
# NameError: name 'model' is not defined

# %%
model.plot_predict(1, 300)
plt.xlabel('Number of months')
plt.ylabel('Percentage return')
plt.show()

# %%
model_two_df = zillow_cleandf[[94027, 90210, 94301, 33480, 94123]]
model_two_df.head()
# Out:
#                 94027      90210     94301     33480     94123
# Date_index
# 1996-04-01  1179200.0  1015400.0  709500.0  958400.0  849100.0
# 1996-05-01  1184300.0  1016900.0  711900.0  958100.0  859000.0
# 1996-06-01  1189700.0  1018400.0  715000.0  957900.0  868800.0
# 1996-07-01  1195400.0  1019800.0  719000.0  957800.0  878400.0
# 1996-08-01  1201200.0  1021400.0  723900.0  958000.0  887800.0

# %%
np.log(model_two_df).plot()
plt.ylabel('log_price');

# %%
# stationary_test = []
# for col in model_two_df:
#     for i in range(1, 10):
#         adf_ = adfuller(model_two_df.diff(i).dropna()[col])[1]
#         stationary_test.append((col, i, adf_))

# [(i[0],i[1],i[2]) for i in stationary_test if i[2] <0.30]

stationary_test = []
for col in model_two_df:
    adf_ = adfuller(model_two_df[col].pct_change().dropna())[1]
    stationary_test.append((col,adf_))

stationary_test
# Out:
# [(94027, 0.40834927841277324),
#  (90210, 0.274500175134474),
#  (94301, 0.1452068074980441),
#  (33480, 0.47372881097802466),
#  (94123, 0.3459804220960678)]

# %%
from model_builder import stationarity_test

# %%
stationarity_test(model_two_df,'pct_change()')
# Out:
# [(94027, 0.40834927841277324),
#  (90210, 0.274500175134474),
#  (94301, 0.1452068074980441),
#  (33480, 0.47372881097802466),
#  (94123, 0.3459804220960678)]

# %%
model_two = ARMA(model_two_df[94301].pct_change().dropna().values, (2,1)).fit()

# %%
model_two.plot_predict(1, 300)
plt.xlabel('Number of months')
plt.ylabel('price difference every two months')
plt.show()
