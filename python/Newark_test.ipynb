# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
from sklearn.model_selection import TimeSeriesSplit
from fbprophet import Prophet

# %%
df = pd.read_csv("../write_data/07106.csv")
df['time'] = pd.to_datetime(df['time'])
df_future = pd.read_csv("../write_data/07106_future.csv")
df_future['ds'] = pd.to_datetime(df_future['ds'])

# %%
df.head()
# Out:
#    Unnamed: 0  RegionName    City State     Metro CountyName        time  \
# 0           0        7106  Newark    NJ  New York      Essex  1996-04-01
# 1           1        7106  Newark    NJ  New York      Essex  1996-05-01
# 2           2        7106  Newark    NJ  New York      Essex  1996-06-01
# 3           3        7106  Newark    NJ  New York      Essex  1996-07-01
# 4           4        7106  Newark    NJ  New York      Essex  1996-08-01
#
#      value          ds    yhat_lower          yhat     yhat_upper  Zip_code  \
# 0  91400.0  1996-04-01  75242.284448  89381.522583  103764.689504      7106
# 1  91300.0  1996-05-01  76020.781069  89325.053094  102950.724202      7106
# 2  91200.0  1996-06-01  75727.120592  89937.150085  103300.827896      7106
# 3  91200.0  1996-07-01  76600.303119  90410.180503  104053.785505      7106
# 4  91200.0  1996-08-01  76450.773480  90887.414080  105164.885425      7106
#
#    log_value   log_yhat
# 0  11.423001  11.400669
# 1  11.421906  11.400037
# 2  11.420810  11.406866
# 3  11.420810  11.412112
# 4  11.420810  11.417377

# %%
plt.plot(df['time'], df['value'], label='actual')
plt.plot(df['time'], df['yhat'], label='fbprophet')
plt.plot(df_future['ds'], df_future['yhat'], label='predict')
plt.legend(loc='best')
plt.show()

# %%
plt.plot(df['time'], df['log_value'], label='actual')
plt.plot(df['time'], df['log_yhat'], label='fbprophet')
plt.plot(df_future['ds'], np.log(df_future['yhat']), label='predict')
plt.legend(loc='best')
plt.show()
