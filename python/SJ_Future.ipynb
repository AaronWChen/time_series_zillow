# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn.model_selection import TimeSeriesSplit
from fbprophet import Prophet

# %%
df_fut = pd.read_csv("../write_data/San Jose_future.csv")
df_fut['ds'] = pd.to_datetime(df_fut['ds'])

# %%
zippies = df_fut.Zip_code.unique()

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[:10]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[10:20]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[20:30]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[30:40]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[40:50]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %%
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(20,10))

# create a color palette
palette = plt.get_cmap('Set1')
num=0

for zippy in zippies[50:]:
    num+=1
    zip_plot = df_fut[df_fut['Zip_code'] == zippy]
    
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    plt.plot(zip_plot['ds'], 
             zip_plot['yhat'], 
             color=palette(num), 
             linewidth=1.9, 
             alpha=0.9, 
             label=zippy)
 
    # Same limits for everybody!
    plt.ylim(400000,4500000)
 
#   # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(zippy, loc='left', fontsize=12, fontweight=0, color=palette(num))

# %%
# 95023

# %%
df_actual = pd.read_csv("../write_data/San Jose.csv")
df_actual['time'] = pd.to_datetime(df_actual['time'])

# %%
df_actual[df_actual['Zip_code'] == 95023]
# Out:
#        Unnamed: 0  RegionName       City State     Metro  CountyName  \
# 15             15       95023  Hollister    CA  San Jose  San Benito
# 70             70       95023  Hollister    CA  San Jose  San Benito
# 125           125       95023  Hollister    CA  San Jose  San Benito
# 180           180       95023  Hollister    CA  San Jose  San Benito
# 235           235       95023  Hollister    CA  San Jose  San Benito
# ...           ...         ...        ...   ...       ...         ...
# 14315       14315       95023  Hollister    CA  San Jose  San Benito
# 14370       14370       95023  Hollister    CA  San Jose  San Benito
# 14425       14425       95023  Hollister    CA  San Jose  San Benito
# 14480       14480       95023  Hollister    CA  San Jose  San Benito
# 14535       14535       95023  Hollister    CA  San Jose  San Benito
#
#             time     value          ds     yhat_lower           yhat  \
# 15    1996-04-01  203700.0  1996-04-01  127359.645503  189312.925749
# 70    1996-05-01  203700.0  1996-05-01  132828.956921  194529.106196
# 125   1996-06-01  203700.0  1996-06-01  144570.117630  198222.456528
# 180   1996-07-01  203600.0  1996-07-01  137111.030379  200442.865474
# 235   1996-08-01  203400.0  1996-08-01  143709.405054  201822.743319
# ...          ...       ...         ...            ...            ...
# 14315 2017-12-01  499400.0  2017-12-01  459866.498440  518744.348313
# 14370 2018-01-01  501000.0  2018-01-01  465551.084189  522412.990233
# 14425 2018-02-01  502600.0  2018-02-01  466162.322389  526235.744436
# 14480 2018-03-01  505600.0  2018-03-01  470998.061668  529649.617927
# 14535 2018-04-01  509600.0  2018-04-01  477039.752003  531313.639636
#
#           yhat_upper  Zip_code  log_value   log_yhat
# 15     252629.035911     95023  12.224404  12.151157
# 70     256126.202717     95023  12.224404  12.178337
# 125    256419.776221     95023  12.224404  12.197145
# 180    260748.486785     95023  12.223913  12.208285
# 235    253979.199419     95023  12.222930  12.215145
# ...              ...       ...        ...        ...
# 14315  575873.764810     95023  13.121163  13.159166
# 14370  577700.469285     95023  13.124361  13.166214
# 14425  585046.173241     95023  13.127550  13.173505
# 14480  590263.677374     95023  13.133501  13.179971
# 14535  587715.547155     95023  13.141381  13.183108
#
# [265 rows x 15 columns]

# %%
# filt = df_actual[df_actual['Zip_code'] == 95023]

# plt.plot([filt['time'], filt['time']], 
#          [filt['value'], filt['yhat']], 
#          label=['actual', 'fbprophet'])

plt.plot(df_actual[df_actual['Zip_code'] == 95023]['time'], 
         df_actual[df_actual['Zip_code'] == 95023]['value'], 
         label='actual')

plt.plot(df_actual[df_actual['Zip_code'] == 95023]['time'], 
         df_actual[df_actual['Zip_code'] == 95023]['yhat'], 
         label='fbprophet')

plt.plot(df_fut[df_fut['Zip_code'] == 95023]['ds'], 
         df_fut[df_fut['Zip_code'] == 95023]['yhat'], 
         label='predict')

plt.plot(df_fut[df_fut['Zip_code'] == 95023]['ds'], 
         df_fut[df_fut['Zip_code'] == 95023]['yhat_lower'], 
         label='predict_lower')

plt.plot(df_fut[df_fut['Zip_code'] == 95023]['ds'], 
         df_fut[df_fut['Zip_code'] == 95023]['yhat_upper'], 
         label='predict_upper')

plt.legend(loc='best')
plt.show()

# %%
Prophet()
